# %% [markdown]
# <a href="https://colab.research.google.com/github/yohanesnuwara/corel/blob/main/notebooks/Corel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone repository Corel
# !git clone https://github.com/yohanesnuwara/corel
# Out:
# Cloning into 'corel'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 39 (delta 9), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (39/39), 5.80 MiB | 11.37 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
import sys
sys.path.append('/content/corel/')

from corel import *

# %%
# Setup Corel
# this will install 2 libraries: azure-blob-storage, ultralytics
setup()

# %%
# Download model
# This will access Azure storage account, container, and blob file
# Model will be downloaded in path: "/content/best (5).pt"
download_model()

# %%
# Predict on core image
path_to_core_image = "/content/corel/core_images"
path_to_model = "/content/best (5).pt"

predict_facies(path_to_core_image, path_to_model)
# Out:
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/107.7 GB disk)
# WARNING ⚠️ /content/best (5).pt appears to require 'dill', which is not in ultralytics requirements.
# AutoInstall will run now for 'dill' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['dill'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 14.8s, installed 1 package: ['dill']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ...
